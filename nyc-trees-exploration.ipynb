# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Read and explore the dataset

# %%
df = pd.read_csv('C:/Users/gulce/ANT-Theano-2-27/additional_resources/datasets/NYC Trees/data_100000.csv')

# %%
df.head()
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
# 4  08/30/2015   189565    223043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...       28
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...       27
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 42 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   created_at  100000 non-null  object
#  1   tree_id     100000 non-null  int64
#  2   block_id    100000 non-null  int64
#  3   the_geom    100000 non-null  object
#  4   tree_dbh    100000 non-null  int64
#  5   stump_diam  100000 non-null  int64
#  6   curb_loc    100000 non-null  object
#  7   status      100000 non-null  object
#  8   health      95007 non-null   object
#  9   spc_latin   95008 non-null   object
#  10  spc_common  95008 non-null   object
#  11  steward     95008 non-null   object
#  12  guards      95008 non-null   object
#  13  sidewalk    95008 non-null   object
#  14  user_type   100000 non-null  object
#  15  problems    95008 non-null   object
#  16  root_stone  100000 non-null  object
#  17  root_grate  100000 non-null  object
# ...

# %% [markdown]
# ### Fill in missing values with the status column and change the dtype of date of creation and add this as a seperate value for possible uses

# %%
df['health'].fillna(df['status'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 42 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   created_at  100000 non-null  object
#  1   tree_id     100000 non-null  int64
#  2   block_id    100000 non-null  int64
#  3   the_geom    100000 non-null  object
#  4   tree_dbh    100000 non-null  int64
#  5   stump_diam  100000 non-null  int64
#  6   curb_loc    100000 non-null  object
#  7   status      100000 non-null  object
#  8   health      100000 non-null  object
#  9   spc_latin   95008 non-null   object
#  10  spc_common  95008 non-null   object
#  11  steward     95008 non-null   object
#  12  guards      95008 non-null   object
#  13  sidewalk    95008 non-null   object
#  14  user_type   100000 non-null  object
#  15  problems    95008 non-null   object
#  16  root_stone  100000 non-null  object
#  17  root_grate  100000 non-null  object
# ...

# %%
df['record_date'] = pd.to_datetime(df['created_at'], format='%m/%d/%Y')

# %%
df.head()
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
# 4  08/30/2015   189565    223043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_senate  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...        16
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...        11
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...        18
# ...

# %%
cols = list(df.columns)
cols = [cols[-1]] + cols[:-1]
df = df[cols]

# %%
df.head()
# Out:
#   record_date  created_at  tree_id  block_id  \
# 0  2015-08-27  08/27/2015   180683    348711
# 1  2015-09-03  09/03/2015   200540    315986
# 2  2015-09-05  09/05/2015   204026    218365
# 3  2015-09-05  09/05/2015   204337    217969
# 4  2015-08-30  08/30/2015   189565    223043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health  ... st_assem st_senate   nta            nta_name  \
# 0   OnCurb  Alive   Fair  ...       28        16  QN17        Forest Hills
# 1   OnCurb  Alive   Fair  ...       27        11  QN49          Whitestone
# ...

# %%
df['spc_latin'].fillna(df['status'], inplace=True)

# %%
df['spc_common'].fillna(df['status'], inplace=True)

# %%
df['steward'].fillna(df['status'], inplace=True)

# %%
df['guards'].fillna(df['status'], inplace=True)

# %%
df['sidewalk'].fillna(df['status'], inplace=True)

# %%
df['problems'].fillna(df['status'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 43 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   record_date  100000 non-null  datetime64[ns]
#  1   created_at   100000 non-null  object
#  2   tree_id      100000 non-null  int64
#  3   block_id     100000 non-null  int64
#  4   the_geom     100000 non-null  object
#  5   tree_dbh     100000 non-null  int64
#  6   stump_diam   100000 non-null  int64
#  7   curb_loc     100000 non-null  object
#  8   status       100000 non-null  object
#  9   health       100000 non-null  object
#  10  spc_latin    100000 non-null  object
#  11  spc_common   100000 non-null  object
#  12  steward      100000 non-null  object
#  13  guards       100000 non-null  object
#  14  sidewalk     100000 non-null  object
#  15  user_type    100000 non-null  object
#  16  problems     100000 non-null  object
#  17  root_stone   100000 non-null  object
# ...

# %% [markdown]
# ### Check if there are any duplicates

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# ### Save the new dataframe as a new csv file

# %%
df.to_csv('C:/Users/gulce/nyc-trees/data_clean_GOOD_ENOUGH.csv')
